# %%
import os
import pickle
import numpy as np
from scipy.io.wavfile import read
import python_speech_features as mfcc
from sklearn import preprocessing
import warnings
warnings.filterwarnings("ignore")

# %%
def get_MFCC(sr,audio):
    features = mfcc.mfcc(audio,sr, 0.025, 0.01, 13,appendEnergy = False)
    feat     = np.asarray(())
    for i in range(features.shape[0]):
        temp = features[i,:]
        if np.isnan(np.min(temp)):
            continue
        else:
            if feat.size == 0:
                feat = temp
            else:
                feat = np.vstack((feat, temp))
    features = feat;
    features = preprocessing.scale(features)
    return features

# %%
#sourcepath = "D:\\pygender\\test_data\\AudioSet\\female_clips\\"
sourcepath = "/home/meghana/Downloads/pygender/test_data/AudioSet/female_clips/"
#path to saved models
modelpath = "/home/meghana/Downloads/pygender/"
#modelpath  = "D:\\pygender\\"

# %%
gmm_files = [os.path.join(modelpath,fname) for fname in
              os.listdir(modelpath) if fname.endswith('.gmm')]

models    = [pickle.load(open(fname,'rb')) for fname in gmm_files]
genders   = [fname.split("\\")[-1].split(".gmm")[0] for fname
              in gmm_files]
files     = [os.path.join(sourcepath,f) for f in os.listdir(sourcepath)
              if f.endswith(".wav")]

# %%
c,t=0,0
for f in files:
    t=t+1
    print(f.split("/")[-1])
    sr, audio  = read(f)
    features   = get_MFCC(sr,audio)
    scores     = None
    log_likelihood = np.zeros(len(models))
    for i in range(len(models)):
        gmm    = models[i]         #checking with each model one by one
        scores = np.array(gmm.score(features))
        log_likelihood[i] = scores.sum()
    winner = np.argmax(log_likelihood)
    if genders[winner]=='/home/meghana/Downloads/pygender/female':
        c=c+1
    print("\tdetected as - ", genders[winner],"\n\tscores:female ",log_likelihood[0],",male ", log_likelihood[1],"\n")
# Out:
# 4qXxbVCuHuw.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18678.330137111283 ,male  -17569.803330730643
#
# 1If_s-8BA2M.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18983.93505377383 ,male  -18406.835023452848
#
# 1HarM99EzG0.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18255.871991986536 ,male  -17288.656981525244
#
# 588LpLnkcHI.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18737.195609513277 ,male  -17749.971296182153
#
# 273zOsJes8Y.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -17644.147936991016 ,male  -16895.759255584846
#
# 1cub3_uCtKs.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18326.98135824297 ,male  -16797.68971641215
#
# --loQn6BCNI.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19606.72095705523 ,male  -18515.577938271203
#
# 6BAv2MKpFeQ.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18334.717522434214 ,male  -17462.532626930046
#
# 4drWL_Zs_wA.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18782.294324458733 ,male  -17804.86534588085
#
# 1APWP5AI4yo.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18834.20861693733 ,male  -17119.11943283351
#
# 48lI9IZsHxE.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -20700.8591916926 ,male  -19700.711215542993
#
# 0eFGBtO3-Sg.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19185.29142278076 ,male  -18136.083409248822
#
# 4aVulGFmbIE.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -21010.571401354195 ,male  -20638.90456011155
#
# 1k1eMJE_hho.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18761.24458954417 ,male  -17444.41777240921
#
# -Ekd-_5e29c.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18557.482267664178 ,male  -17357.983234187024
#
# 4zOYDrLVZzo.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18198.899004194114 ,male  -17672.75329012034
#
# 1Byis6WPWkk.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18436.578335245405 ,male  -17648.953345921174
#
# 1Cow7LnVss4.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -20015.589436887625 ,male  -19485.936874124658
#
# 4m_rSC_jV6k.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18816.595957016834 ,male  -18164.82473458701
#
# 3My3TWp4ZrI.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19604.209997609323 ,male  -19334.674548836934
#
# 2POub4l90n4.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19227.49734463385 ,male  -17240.092015774455
#
# -NL7tuUyLDM.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -
.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18791.43282870664 ,male  -18319.118583334588
#
# 1W8ly-8kFt0.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19541.278042597893 ,male  -19298.354078821387
#
# 0B4Zd7MJYjk.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19513.70647773675 ,male  -19135.203032166217
#
# 1qQ0OCG3nQo.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19103.305382976432 ,male  -18807.977353358307
#
# -oO2IvCE_yA.wav
# 	detected as -  /home/meghana/Downloads/pygender/male
# 	scores:female  -19185.84256283432 ,male  -19412.873553633308
#
# 2flcW_FbnZU.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19076.032895134605 ,male  -17571.892733782006
#
# 4-i9WsjCFj8.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18840.110697609387 ,male  -18469.9805431606
#
# 1gYM0z1AP6I.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19847.951457835006 ,male  -19261.823273100497
#
# 0Z-yS4Pvwvw.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -11792.846087051854 ,male  -11511.718659540544
#
# 2ljQVlmRqOI.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -17965.71324661916 ,male  -17522.72460620921
#
# 30s7YiUQ3RE.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18050.556862720186 ,male  -17443.408041302868
#
# 3xclJdr4dek.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -20347.447132684305 ,male  -19963.390916055396
#
# 2QZmSEzCgUk.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19066.426272222325 ,male  -18522.5092720815
#
# 0XpEG6ryHQA.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -20721.641085080097 ,male  -20432.97451246081
#
# 4494cj35eoM.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -20061.335332647297 ,male  -19595.836540003682
#
# 6CT4WLbGmc4.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19409.653837455873 ,male  -18499.412713862166
#
# 5wpJUpFnfvs.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19362.390762752224 ,male  -18116.17988844229
#
# 5oF9nq8ykek.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18620.911982374586 ,male  -17361.399055004134
#
# -w6gKdlJZTY.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19672.12658972901 ,male  -18274.03266592537
#
# 0mipnG5k564.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19957.215091051825 ,male  -19016.312555168384
#
# 04e9N_422v0.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18125.88095722791 ,male  -17212.003550210167
#
# 2f4s67hUx1Q.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18095.507646728416 ,male  -17471.17482543688
#
# 3gUPjyXigzE.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -20243.37285690129 ,male  -19713.35317794303
#
# 2nmGk1I-PaM.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18324.131384422493 ,male  -17215.334422714033
#
# 4Fbprv9eVoY.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19758.765502256763 ,male  -19225.211485949112
#
# 3dvCFqBuud0.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18169.296648271345 ,male  -16528.648628994728
#
# -jjWi-og5Qs.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19739.94725903406 ,male  -18109.365159774054
#
# 178NyD2I37s.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19622.876927773028 ,male  -19486.302953931503
#
# 0mxcPwCLUb0.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18190.85428021541 ,male  -17673.832989240836
#
# 3gL-av1-BUA.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -17907.928908194644 ,male  -17376.816855820714
#
# 4rSIgRMjMqo.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18996.688485998042 ,male  -18373.544711088296
#
# 1HpaISOYlJc.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18373.67234499592 ,male  -17561.02266798199
#
# 4QWRQw-W6ss.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18760.80883621889 ,male  -17530.899082623826
#
# 3RniDh2rgTI.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19004.454114328353 ,male  -18527.968481032603
#
# 6HNGoQ6Z9Ms.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19776.062929508604 ,male  -19215.099962954184
#
# 5fGaQdH-wLw.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18432.773222161453 ,male  -17848.324220039387
#
# -_m_h0DBaxw.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18642.1371886466 ,male  -17868.279683744302
#
# -IAuM2eOMKI.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -20374.6654225205 ,male  -19726.396391879454
#
# 1U1C8oH-kWM.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18878.716670881102 ,male  -17116.82543000676
#
# 39plKCacEMM.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19579.979548350264 ,male  -18871.289921003314
#
# 3WY6ee7oPCc.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19579.0390398444 ,male  -18610.674455740955
#
# 5p8JjptnZGo.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18998.25501871237 ,male  -18489.77573530782
#
# 54F98NkNUQY.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19600.457255257315 ,male  -18157.984910266096
#
# 1dnFZNXz9_A.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19147.436098824528 ,male  -18716.812179705732
#
# 0wb1u-T46ZA.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18563.585753202 ,male  -18165.441759908994
#
# -RdwbndKkac.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18601.091807095094 ,male  -18325.713193448453
#
# 2JhpopjcJS0.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18412.78298541101 ,male  -17480.380905582337
#
# -de3vPE8Hls.wav
# 	detected as -  /home/meghana/Downloads/pygender/male
# 	scores:female  -19325.295594068655 ,male  -19362.839961016805
#
# 0TiPjkcR_Vs.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -17837.11960141116 ,male  -17318.04572716371
#
# 4lBTenfUFoU.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18883.02973651272 ,male  -18249.86987741832
#
# 0EyRvpCdD3M.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -20758.541022868365 ,male  -20586.843884549246
#
# 5xfYPjDNRf4.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18137.07297004557 ,male  -17659.632825581994
#
# 3cflSj0FASU.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19862.386202069276 ,male  -19640.14967541062
#
# 1ZDUp5E1ZzI.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -17889.331927583138 ,male  -16840.77212990431
#
# 4M4IMk2YApk.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18850.951190614152 ,male  -18415.239614861486
#
# -mhpQRL24PM.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18780.084927783384 ,male  -17768.02381148813
#
# 2iZsq34S72I.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19488.67838566393 ,male  -18203.736406014985
#
# 0HhzZVQS_xc.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18202.562447182983 ,male  -17150.96058992512
#
# 1uyHRtI8mW0.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18813.723745432268 ,male  -18534.224105432426
#
# 2-v0OLy6xxs.wav
# 	detected as -  /home/meghana/Downloads/pygender/male
# 	scores:female  -20236.202838551784 ,male  -20287.6048436853
#
# 6CB79qSX5oI.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18334.557402014383 ,male  -17452.152545359866
#
# 2QZTY-iCR9o.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18789.280611209015 ,male  -18034.61408964471
#
# 2ll7CeyebZo.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18964.297321654845 ,male  -18303.75857342001
#
# 3qsJ_Matdso.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -20682.71121712362 ,male  -19798.24625217991
#
# 5EMBN_76P3Y.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -21180.753852939175 ,male  -20533.287716525105
#
# 65me0Xyv79c.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -16961.385424456814 ,male  -16935.903908057833
#
# 3rFLBLhYTd8.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18843.50345681577 ,male  -18638.64008961666
#
# 09wYHMyHW_k.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -17962.61787483935 ,male  -17419.33371133663
#
# 0bIb6Pjzk1g.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19396.434385389468 ,male  -18279.436615731564
#
# -FjfDlyXXPI.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18369.067252014844 ,male  -16966.01010046743
#
# 6DCjY3ELFeE.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18486.023398369798 ,male  -16922.36000765978
#
# 34KJJLpw4Ck.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19142.302042588402 ,male  -18369.77560177502
#
# 3KKAEAGT5DY.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -20481.845529457736 ,male  -20019.62396125422
#
# 0L3A5mZXHUs.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -17421.40545088717 ,male  -16592.058314911657
#
# 4D-8LFC_eMU.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18880.47500530117 ,male  -17640.69654031942
#
# 1Ypu4qbbQDA.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -20275.16470508391 ,male  -19494.51714256071
#
# 0ejhK6V8EtI.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -17996.869026608023 ,male  -17161.441059306148
#
# 4TyzMcpMlv0.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19880.09464940426 ,male  -19031.862683711934
#
# 3riLt6CscP0.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -18033.443564931313 ,male  -17098.001855556045
#
# 1RrMaovFW4g.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19262.082462213475 ,male  -17836.52615025972
#
# 1HOuMsiWyXc.wav
# 	detected as -  /home/meghana/Downloads/pygender/female
# 	scores:female  -19368.822593127974 ,male  -18369.203790629123
#
# 1nQ7cgeXf40.wav
# 	detected as -  /home/meghana/Downloads/pygender/male
# 	scores:female  -19255.025977569116 ,male  -19282.570474316763
#
# -SlN4B7PpvM.wav

# %%
c/t
